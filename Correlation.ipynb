# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Correlación lineal de Pearson

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/dws_1/sub_1.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0           0       1.528132       -0.733896      0.696372   0.741895
# 1           1       1.527992       -0.716987      0.677762   0.753099
# 2           2       1.527765       -0.706999      0.670951   0.759611
# 3           3       1.516768       -0.704678      0.675735   0.760709
# 4           4       1.493941       -0.703918      0.672994   0.760062
#
#    gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0   0.669768  -0.031672        0.316738        0.778180        1.082764
# 1   0.657116  -0.032255        0.842032        0.424446        0.643574
# 2   0.649555  -0.032707       -0.138143       -0.040741        0.343563
# 3   0.647788  -0.041140       -0.025005       -1.048717        0.035860
# 4   0.647210  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z
# ...

# %%
del df['Unnamed: 0']
df.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z
# 0            0.294894           -0.184493            0.377542
# ...

# %%
for feat in df:
    plt.figure()
    plt.title(feat)
    plt.plot(df[feat])

# %%
df.corr(method="pearson")
# Out:
#                     attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# attitude.roll            1.000000       -0.174992      0.017448   0.244522
# attitude.pitch          -0.174992        1.000000      0.408419   0.870057
# attitude.yaw             0.017448        0.408419      1.000000   0.393436
# gravity.x                0.244522        0.870057      0.393436   1.000000
# gravity.y                0.176398       -0.997818     -0.414980  -0.861289
# gravity.z                0.989750       -0.259796     -0.019386   0.166455
# rotationRate.x           0.300941        0.024358     -0.132540   0.173899
# rotationRate.y           0.137303       -0.081630     -0.054435  -0.002022
# rotationRate.z          -0.058952        0.079436     -0.019424   0.064475
# userAcceleration.x       0.255000       -0.316406     -0.103988  -0.166032
# userAcceleration.y      -0.104904        0.245931      0.189223   0.210132
# ...

# %%
df.corr()
# Out:
#                     attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# attitude.roll            1.000000       -0.174992      0.017448   0.244522
# attitude.pitch          -0.174992        1.000000      0.408419   0.870057
# attitude.yaw             0.017448        0.408419      1.000000   0.393436
# gravity.x                0.244522        0.870057      0.393436   1.000000
# gravity.y                0.176398       -0.997818     -0.414980  -0.861289
# gravity.z                0.989750       -0.259796     -0.019386   0.166455
# rotationRate.x           0.300941        0.024358     -0.132540   0.173899
# rotationRate.y           0.137303       -0.081630     -0.054435  -0.002022
# rotationRate.z          -0.058952        0.079436     -0.019424   0.064475
# userAcceleration.x       0.255000       -0.316406     -0.103988  -0.166032
# userAcceleration.y      -0.104904        0.245931      0.189223   0.210132
# ...

# %%
plt.matshow(df.corr())

# %%
plt.plot(df["attitude.roll"], df["gravity.z"], "ro")
plt.xlabel("attitude.roll")
plt.ylabel("gravity.z")
# Out:
# Text(0, 0.5, 'gravity.z')

# %%
plt.plot(df["attitude.roll"], df["gravity.y"], "ro")
plt.xlabel("attitude.roll")
plt.ylabel("gravity.y")
# Out:
# Text(0, 0.5, 'gravity.y')

# %%
plt.plot(df["attitude.pitch"], df["gravity.x"], "ro")
plt.xlabel("attitude.pitch")
plt.ylabel("gravity.x")
# Out:
# Text(0, 0.5, 'gravity.x')

# %%
plt.plot(df["attitude.pitch"], df["gravity.y"], "ro")
plt.xlabel("attitude.pitch")
plt.ylabel("gravity.y")
# Out:
# Text(0, 0.5, 'gravity.y')

# %% [markdown]
# Correlación no lineal de Spearman

# %%
df.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z
# 0            0.294894           -0.184493            0.377542
# ...

# %%
df.corr(method="spearman")
# Out:
#                     attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# attitude.roll            1.000000       -0.140588      0.103890   0.246469
# attitude.pitch          -0.140588        1.000000      0.301719   0.875059
# attitude.yaw             0.103890        0.301719      1.000000   0.332761
# gravity.x                0.246469        0.875059      0.332761   1.000000
# gravity.y                0.140586       -1.000000     -0.301720  -0.875059
# gravity.z                0.994852       -0.210412      0.078384   0.181526
# rotationRate.x           0.308231        0.017204     -0.141627   0.176933
# rotationRate.y           0.131870       -0.076355     -0.004842  -0.007286
# rotationRate.z          -0.041406        0.087176     -0.060878   0.089048
# userAcceleration.x       0.257723       -0.331043     -0.068949  -0.166549
# userAcceleration.y      -0.136073        0.290343      0.204624   0.227793
# ...

# %%
df.corr()
# Out:
#                     attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# attitude.roll            1.000000       -0.174992      0.017448   0.244522
# attitude.pitch          -0.174992        1.000000      0.408419   0.870057
# attitude.yaw             0.017448        0.408419      1.000000   0.393436
# gravity.x                0.244522        0.870057      0.393436   1.000000
# gravity.y                0.176398       -0.997818     -0.414980  -0.861289
# gravity.z                0.989750       -0.259796     -0.019386   0.166455
# rotationRate.x           0.300941        0.024358     -0.132540   0.173899
# rotationRate.y           0.137303       -0.081630     -0.054435  -0.002022
# rotationRate.z          -0.058952        0.079436     -0.019424   0.064475
# userAcceleration.x       0.255000       -0.316406     -0.103988  -0.166032
# userAcceleration.y      -0.104904        0.245931      0.189223   0.210132
# ...

# %%
plt.matshow(df.corr(method="spearman"))

# %% [markdown]
# Autocorrelación

# %%
import numpy as np

# %%
roll = np.asarray(df["attitude.roll"])
roll = roll - roll.mean()

# %%
cor = np.correlate(roll, roll, mode='full')

# %%
plt.plot(cor)

# %%
for i, col in enumerate(df):
    cor = np.correlate(df[col], df[col], mode='full')
    plt.subplot(6, 2, i + 1)
    plt.plot(cor)
