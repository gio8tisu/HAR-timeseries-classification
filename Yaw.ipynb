# %% [markdown]
# Attitude Diagram

# %% [markdown]
# ![attitude diagram](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Yaw_Axis_Corrected.svg/319px-Yaw_Axis_Corrected.svg.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/dws_1/sub_1.csv")
del df['Unnamed: 0']
df.head()

# %% [markdown]
# Down-stairs yaw

# %%
plt.figure()
plt.title("dws attitude.yaw")
plt.plot(df["attitude.yaw"])

# %% [markdown]
# Jogging yaw

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/jog_16/sub_1.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("jog attitude.yaw")
plt.plot(df["attitude.yaw"])

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/jog_16/sub_21.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("jog attitude.yaw")
plt.plot(df["attitude.yaw"])

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/jog_16/sub_6.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("jog attitude.yaw")
plt.plot(df["attitude.yaw"])

# %% [markdown]
# Sitting yaw

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/sit_13/sub_10.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("sit attitude.yaw")
plt.plot(df["attitude.yaw"])

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/sit_13/sub_1.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("sit attitude.yaw")
plt.plot(df["attitude.yaw"])

# %% [markdown]
# Standing yaw

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/std_14/sub_10.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("std attitude.yaw")
plt.plot(df["attitude.yaw"])

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/std_14/sub_1.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("std attitude.yaw")
plt.plot(df["attitude.yaw"])

# %% [markdown]
# Up-stairs yaw

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/ups_12/sub_1.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("ups attitude.yaw")
plt.plot(df["attitude.yaw"])

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/ups_12/sub_10.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("ups attitude.yaw")
plt.plot(df["attitude.yaw"])

# %% [markdown]
# Walk yaw

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/wlk_15/sub_10.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("wlk attitude.yaw")
plt.plot(df["attitude.yaw"])

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/wlk_15/sub_1.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("wlk attitude.yaw")
plt.plot(df["attitude.yaw"])

# %%
df = pd.read_csv("motionsense-dataset/A_DeviceMotion_data/A_DeviceMotion_data/wlk_15/sub_16.csv")
del df['Unnamed: 0']
plt.figure()
plt.title("wlk attitude.yaw")
plt.plot(df["attitude.yaw"])
