# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import sklearn.preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd

import sklearn.pipeline
from sklearn.compose import ColumnTransformer
from transforms import FourierTransform, MeanTransform, NormTransform

# %%
from dataset import HARDatasetCrops

# %% [markdown]
# ## Data

# %% [markdown]
# ### Features

# %%
dataset = HARDatasetCrops('motionsense-dataset/train', 256, 50, 50, metadata_file='motionsense-dataset/data_subjects_info.csv')

# %%
print('Dataset size:', len(dataset))

sample = dataset[0][0]
print('Datapoints shape:', sample.shape)
# Out:
# Dataset size: 4095
# Datapoints shape: (256, 12)

# %% [markdown]
# Our dataset is composed of 5205 datapoints, each have shape `(256, 12)` because we have 12 signals of 256 samples each.

# %%
X_roll = np.array([sample[:,0] for sample, _, _ in dataset])
X_pitch = np.array([sample[:,1] for sample, _, _ in dataset])
X_yaw = np.array([sample[:,2] for sample, _, _ in dataset])
X_gx = np.array([sample[:,3] for sample, _, _ in dataset])
X_gy = np.array([sample[:,4] for sample, _, _ in dataset])
X_gz = np.array([sample[:,5] for sample, _, _ in dataset])
X_acc = np.array([np.linalg.norm(sample[:,6:9], axis=1) for sample, _, _ in dataset])
X_rot = np.array([np.linalg.norm(sample[:,9:12], axis=1) for sample, _, _ in dataset])

# %% [markdown]
# ### Classes

# %% [markdown]
# The classes are the following:

# %%
dataset.CLASSES
# Out:
# {'dws': 'down-stairs',
#  'ups': 'up-stairs',
#  'wlk': 'walk',
#  'std': 'standing',
#  'sit': 'sitting',
#  'jog': 'jogging'}

# %% [markdown]
# In order to fit a `sklearn` model we should encode each class with a unique integer:

# %%
label_encoder = sklearn.preprocessing.LabelEncoder()
label_encoder.fit(list(dataset.CLASSES.keys()));

# %%
y = label_encoder.transform([cls for _, cls, _ in dataset])

# %%
sns.countplot(label_encoder.inverse_transform(y));

# %% [markdown]
# #### Train-test splitting

# %% [markdown]
# We will first "stack" our features.

# %%
X = np.hstack([X_roll,
               X_pitch,
               X_yaw,
               X_gx,
               X_gy,
               X_gz,
               X_acc,
               X_rot])

X.shape
# Out:
# (4095, 2048)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %%
print('Number of training examples:', y_train.shape[0])
print('Number of testing examples:', y_test.shape[0])
# Out:
# Number of training examples: 2743
# Number of testing examples: 1352

# %% [markdown]
# #### PCA feature reduction

# %%
roll_transform = sklearn.pipeline.make_pipeline(
    MeanTransform()
)
pitch_transform = sklearn.pipeline.make_pipeline(
    MeanTransform()
)
yaw_transform = sklearn.pipeline.make_pipeline(
    MeanTransform()
)
gx_transform = sklearn.pipeline.make_pipeline(
    MeanTransform()
)
gy_transform = sklearn.pipeline.make_pipeline(
    MeanTransform()
)
gz_transform = sklearn.pipeline.make_pipeline(
    MeanTransform()
)
acc_transform = sklearn.pipeline.make_pipeline(
    FourierTransform(),
    PCA(n_components=32)
)
rot_transform = sklearn.pipeline.make_pipeline(
    FourierTransform(),
    PCA(n_components=32)
)

# %%
features = ColumnTransformer([
    ("roll", roll_transform, slice(0, 256)),
    ("pitch", pitch_transform, slice(256, 512)),
    ("yaw", yaw_transform, slice(512, 768)),
    ("gravity-x", gx_transform, slice(768, 1024)),
    ("gravity-y", gy_transform, slice(1024, 1280)),
    ("gravity-z", gz_transform, slice(1280, 1536)),
    ("accelaration", acc_transform, slice(1536, 1792)),
    ("rotation", rot_transform, slice(1792, 2048))
])

# %% [markdown]
# ## Visualization

# %%
X_feats = features.fit_transform(X)

# %%
X_feats.shape
# Out:
# (4095, 70)

# %%
df = pd.DataFrame({'roll': X_feats[:, 0],
                   'pitch': X_feats[:, 1],
                   'yaw': X_feats[:, 2],
                   'gravity-x': X_feats[:, 3],
                   'gravity-y': X_feats[:, 4],
                   'gravity-z': X_feats[:, 5],
                   'accelaration-mag': X_feats[:, 6],
                   'rotation-mag': X_feats[:, 7],
                   'class': [cls for _, cls, _ in dataset]})
df.head()
# Out:
#        roll     pitch       yaw  gravity-x  gravity-y  gravity-z  \
# 0 -0.709532 -1.248550  1.619969  -0.155536   0.943408  -0.203484
# 1 -1.189034 -1.205130 -1.983140  -0.295149   0.930866  -0.119316
# 2 -0.503057 -1.265631  2.608484  -0.088673   0.943192  -0.242026
# 3 -0.139033 -1.354976 -0.413806   0.007792   0.965574  -0.171450
# 4 -0.126664 -1.286526  2.372528   0.001018   0.945968  -0.255983
#
#    accelaration-mag  rotation-mag class
# 0        235.814015      5.847377   dws
# 1        311.851165    -22.643960   dws
# 2        241.254038      9.531517   dws
# 3        246.794010      8.748038   dws
# 4        192.628559     -3.203159   dws

# %%
sns.pairplot(df, hue="class")

# %% [markdown]
# ## Classification

# %%
import sklearn.discriminant_analysis

# %%
clf = sklearn.pipeline.make_pipeline(
    features,
    sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis()
)
clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('roll',
#                                                   Pipeline(memory=None,
#                                                            steps=[('meantransform',
#                                                                    MeanTransform())],
#                                                            verbose=False),
#                                                   slice(0, 256, None)),
#                                                  ('pitch',
#                                                   Pipeline(memory=None,
#                                                            steps=[('meantransform',
#                                                                    MeanTransform())],
#                                                            verbose=False),
#                                                   sl...
#                                                            steps=[('fouriertransform',
#                                                                    FourierTransform(window=None)),
#                                                                   ('pca',
#                                                                    PCA(copy=True,
#                                                                        iterated_power='auto',
#                                                                        n_components=32,
#                                                                        random_state=None,
#                                                                        svd_solver='auto',
#                                                                        tol=0.0,
#                                                                        whiten=False))],
#                                                            verbose=False),
#                                                   slice(1792, 2048, None))],
#                                    verbose=False)),
#                 ('quadraticdiscriminantanalysis',
#                  QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                                                store_covariance=False,
#                                                tol=0.0001))],
#          verbose=False)

# %%
print(classification_report(y_train, clf.predict(X_train), target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          dws       1.00      0.98      0.99       236
#          jog       1.00      1.00      1.00       265
#          sit       1.00      1.00      1.00       663
#          std       1.00      0.99      0.99       615
#          ups       0.91      1.00      0.95       298
#          wlk       1.00      0.98      0.99       666
#
#     accuracy                           0.99      2743
#    macro avg       0.99      0.99      0.99      2743
# weighted avg       0.99      0.99      0.99      2743

# %%
plot_confusion_matrix(clf, X_train, y_train,
                      display_labels=label_encoder.classes_,
                      cmap=plt.cm.Blues,
                      normalize="true")

# %%
print(classification_report(y_test, clf.predict(X_test), target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          dws       0.96      0.86      0.91       123
#          jog       0.98      1.00      0.99       119
#          sit       1.00      0.96      0.98       341
#          std       0.99      0.95      0.97       285
#          ups       0.78      0.99      0.87       138
#          wlk       0.98      0.98      0.98       346
#
#     accuracy                           0.96      1352
#    macro avg       0.95      0.96      0.95      1352
# weighted avg       0.96      0.96      0.96      1352

# %%
plot_confusion_matrix(clf, X_test, y_test,
                      display_labels=label_encoder.classes_,
                      cmap=plt.cm.Blues,
                      normalize="true")

# %% [markdown]
# ## Metadata

# %%
metadata = np.array([metadata for _, _, metadata in dataset])

# %%
metadata.shape
# Out:
# (4095, 4)

# %%
X = np.hstack([X, metadata])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %% [markdown]
# #### PCA feature reduction

# %%
features = ColumnTransformer([
    ("roll", roll_transform, slice(0, 256)),
    ("pitch", pitch_transform, slice(256, 512)),
    ("yaw", yaw_transform, slice(512, 768)),
    ("gravity-x", gx_transform, slice(768, 1024)),
    ("gravity-y", gy_transform, slice(1024, 1280)),
    ("gravity-z", gz_transform, slice(1280, 1536)),
    ("accelaration", acc_transform, slice(1536, 1792)),
    ("rotation", rot_transform, slice(1792, 2048)),
    ("metadata", "passthrough", slice(-4, X.shape[1]))
])

# %%
clf = sklearn.pipeline.make_pipeline(
    features,
    sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis()
)
clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('roll',
#                                                   Pipeline(memory=None,
#                                                            steps=[('meantransform',
#                                                                    MeanTransform())],
#                                                            verbose=False),
#                                                   slice(0, 256, None)),
#                                                  ('pitch',
#                                                   Pipeline(memory=None,
#                                                            steps=[('meantransform',
#                                                                    MeanTransform())],
#                                                            verbose=False),
#                                                   sl...
#                                                                    PCA(copy=True,
#                                                                        iterated_power='auto',
#                                                                        n_components=32,
#                                                                        random_state=None,
#                                                                        svd_solver='auto',
#                                                                        tol=0.0,
#                                                                        whiten=False))],
#                                                            verbose=False),
#                                                   slice(1792, 2048, None)),
#                                                  ('metadata', 'passthrough',
#                                                   slice(-4, 2052, None))],
#                                    verbose=False)),
#                 ('quadraticdiscriminantanalysis',
#                  QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                                                store_covariance=False,
#                                                tol=0.0001))],
#          verbose=False)

# %%
print(classification_report(y_train, clf.predict(X_train), target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          dws       0.99      0.99      0.99       236
#          jog       1.00      1.00      1.00       265
#          sit       1.00      1.00      1.00       663
#          std       1.00      1.00      1.00       615
#          ups       0.95      1.00      0.97       298
#          wlk       1.00      0.98      0.99       666
#
#     accuracy                           0.99      2743
#    macro avg       0.99      0.99      0.99      2743
# weighted avg       0.99      0.99      0.99      2743

# %%
plot_confusion_matrix(clf, X_train, y_train,
                      display_labels=label_encoder.classes_,
                      cmap=plt.cm.Blues,
                      normalize="true")

# %%
print(classification_report(y_test, clf.predict(X_test), target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          dws       0.93      0.93      0.93       123
#          jog       0.98      1.00      0.99       119
#          sit       1.00      0.96      0.98       341
#          std       0.99      0.96      0.97       285
#          ups       0.83      0.98      0.90       138
#          wlk       0.99      0.98      0.98       346
#
#     accuracy                           0.97      1352
#    macro avg       0.95      0.97      0.96      1352
# weighted avg       0.97      0.97      0.97      1352

# %%
plot_confusion_matrix(clf, X_test, y_test,
                      display_labels=label_encoder.classes_,
                      cmap=plt.cm.Blues,
                      normalize="true")

# %% [markdown]
# ## SVM
#
# Use SVM with hyperparameters found in previous CV search.

# %%
import sklearn.svm

# %%
clf = sklearn.pipeline.make_pipeline(
    features,
    sklearn.svm.SVC(C=10000, gamma=0.0001, kernel="rbf")
)
clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('roll',
#                                                   Pipeline(memory=None,
#                                                            steps=[('meantransform',
#                                                                    MeanTransform())],
#                                                            verbose=False),
#                                                   slice(0, 256, None)),
#                                                  ('pitch',
#                                                   Pipeline(memory=None,
#                                                            steps=[('meantransform',
#                                                                    MeanTransform())],
#                                                            verbose=False),
#                                                   sl...
#                                                            verbose=False),
#                                                   slice(1792, 2048, None)),
#                                                  ('metadata', 'passthrough',
#                                                   slice(-4, 2052, None))],
#                                    verbose=False)),
#                 ('svc',
#                  SVC(C=10000, break_ties=False, cache_size=200,
#                      class_weight=None, coef0=0.0,
#                      decision_function_shape='ovr', degree=3, gamma=0.0001,
#                      kernel='rbf', max_iter=-1, probability=False,
#                      random_state=None, shrinking=True, tol=0.001,
#                      verbose=False))],
#          verbose=False)

# %%
print(classification_report(y_train, clf.predict(X_train), target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          dws       1.00      1.00      1.00       236
#          jog       1.00      1.00      1.00       265
#          sit       1.00      1.00      1.00       663
#          std       1.00      1.00      1.00       615
#          ups       1.00      1.00      1.00       298
#          wlk       1.00      1.00      1.00       666
#
#     accuracy                           1.00      2743
#    macro avg       1.00      1.00      1.00      2743
# weighted avg       1.00      1.00      1.00      2743

# %%
plot_confusion_matrix(clf, X_train, y_train,
                      display_labels=label_encoder.classes_,
                      cmap=plt.cm.Blues,
                      normalize="true")

# %%
print(classification_report(y_test, clf.predict(X_test), target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          dws       0.97      0.89      0.93       123
#          jog       0.94      0.99      0.96       119
#          sit       1.00      0.99      1.00       341
#          std       0.99      1.00      1.00       285
#          ups       0.94      0.97      0.96       138
#          wlk       0.99      0.99      0.99       346
#
#     accuracy                           0.98      1352
#    macro avg       0.97      0.97      0.97      1352
# weighted avg       0.98      0.98      0.98      1352

# %%
plot_confusion_matrix(clf, X_test, y_test,
                      display_labels=label_encoder.classes_,
                      cmap=plt.cm.Blues,
                      normalize="true")

# %% [markdown]
# ### Hyperparameter search

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import GridSearchCV

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.15, random_state=0)

# %%
clf = sklearn.pipeline.make_pipeline(
    features,
    sklearn.svm.SVC()
)

# %%
param_grid =  {
    'svc__C': [1, 10, 100, 1000, 10000],
    'svc__gamma': [0.001, 0.0001, 0.00001],
    'svc__kernel': ['linear', 'rbf']
}

# %%
grid_search = GridSearchCV(clf, param_grid, cv=cv)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=5, random_state=0, test_size=0.15, train_size=None),
#              error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('columntransformer',
#                                         ColumnTransformer(n_jobs=None,
#                                                           remainder='drop',
#                                                           sparse_threshold=0.3,
#                                                           transformer_weights=None,
#                                                           transformers=[('roll',
#                                                                          Pipeline(memory=None,
#                                                                                   steps=[('meantransform',
#                                                                                           MeanTransform())],
#                                                                                   verbose=Fa...
#                                             degree=3, gamma='scale',
#                                             kernel='rbf', max_iter=-1,
#                                             probability=False,
#                                             random_state=None, shrinking=True,
#                                             tol=0.001, verbose=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'svc__C': [1, 10, 100, 1000, 10000],
#                          'svc__gamma': [0.001, 0.0001, 1e-05],
#                          'svc__kernel': ['rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
grid_search.best_params_
# Out:
# {'svc__C': 10000, 'svc__gamma': 1e-05, 'svc__kernel': 'rbf'}

# %%
grid_search.best_score_
# Out:
# 0.9878640776699029

# %%
import pandas as pd

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)

# %%
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_svc__C  \
# 0        0.778944      0.028916         0.072447        0.002957            1
# 1        0.461205      0.009092         0.061614        0.003119            1
# 2        0.282673      0.018058         0.056096        0.004940            1
# 3        0.881472      0.038076         0.071503        0.005288           10
# 4        0.453147      0.018935         0.054577        0.004598           10
# 5        0.257360      0.010787         0.043374        0.002247           10
# 6        0.869077      0.013963         0.066797        0.003108          100
# 7        0.431455      0.026065         0.044876        0.002773          100
# 8        0.249266      0.017428         0.038360        0.003177          100
# 9        0.834515      0.021807         0.062773        0.002150         1000
# 10       0.418567      0.008117         0.041717        0.003213         1000
# 11       0.233870      0.017039         0.025446        0.001267         1000
# 12       0.788880      0.039520         0.061194        0.001088        10000
# 13       0.397451      0.011027         0.038345        0.000341        10000
# 14       0.205099      0.005553         0.018804        0.000262        10000
#
#    param_svc__gamma param_svc__kernel  \
# 0             0.001               rbf
# 1            0.0001               rbf
# 2             1e-05               rbf
# 3             0.001               rbf
# 4            0.0001               rbf
# 5             1e-05               rbf
# 6             0.001               rbf
# 7            0.0001               rbf
# 8             1e-05               rbf
# 9             0.001               rbf
# 10           0.0001               rbf
# 11            1e-05               rbf
# 12            0.001               rbf
# 13           0.0001               rbf
# 14            1e-05               rbf
#
#                                                params  split0_test_score  \
# 0   {'svc__C': 1, 'svc__gamma': 0.001, 'svc__kerne...           0.677184
# 1   {'svc__C': 1, 'svc__gamma': 0.0001, 'svc__kern...           0.915049
# 2   {'svc__C': 1, 'svc__gamma': 1e-05, 'svc__kerne...           0.873786
# 3   {'svc__C': 10, 'svc__gamma': 0.001, 'svc__kern...           0.723301
# 4   {'svc__C': 10, 'svc__gamma': 0.0001, 'svc__ker...           0.946602
# 5   {'svc__C': 10, 'svc__gamma': 1e-05, 'svc__kern...           0.917476
# 6   {'svc__C': 100, 'svc__gamma': 0.001, 'svc__ker...           0.725728
# 7   {'svc__C': 100, 'svc__gamma': 0.0001, 'svc__ke...           0.983010
# 8   {'svc__C': 100, 'svc__gamma': 1e-05, 'svc__ker...           0.956311
# 9   {'svc__C': 1000, 'svc__gamma': 0.001, 'svc__ke...           0.725728
# 10  {'svc__C': 1000, 'svc__gamma': 0.0001, 'svc__k...           0.983010
# 11  {'svc__C': 1000, 'svc__gamma': 1e-05, 'svc__ke...           0.987864
# 12  {'svc__C': 10000, 'svc__gamma': 0.001, 'svc__k...           0.725728
# 13  {'svc__C': 10000, 'svc__gamma': 0.0001, 'svc__...           0.983010
# 14  {'svc__C': 10000, 'svc__gamma': 1e-05, 'svc__k...           0.990291
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.677184           0.682039           0.672330
# 1            0.905340           0.910194           0.898058
# 2            0.866505           0.893204           0.849515
# 3            0.720874           0.723301           0.723301
# 4            0.939320           0.944175           0.946602
# 5            0.905340           0.919903           0.900485
# 6            0.723301           0.723301           0.725728
# 7            0.978155           0.970874           0.985437
# 8            0.944175           0.958738           0.939320
# 9            0.723301           0.723301           0.725728
# 10           0.978155           0.973301           0.985437
# 11           0.990291           0.990291           0.987864
# 12           0.723301           0.723301           0.725728
# 13           0.980583           0.968447           0.985437
# 14           0.987864           0.990291           0.987864
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.626214         0.666990        0.020618               15
# 1            0.888350         0.903398        0.009388                9
# 2            0.866505         0.869903        0.014119               10
# 3            0.684466         0.715049        0.015320               14
# 4            0.932039         0.941748        0.005535                7
# 5            0.893204         0.907282        0.010113                8
# 6            0.684466         0.716505        0.016056               11
# 7            0.978155         0.979126        0.004998                5
# 8            0.932039         0.946117        0.010113                6
# 9            0.684466         0.716505        0.016056               11
# 10           0.980583         0.980097        0.004176                3
# 11           0.978155         0.986893        0.004502                2
# 12           0.684466         0.716505        0.016056               11
# 13           0.980583         0.979612        0.005866                4
# 14           0.983010         0.987864        0.002659                1

# %%
print(classification_report(y_train, grid_search.predict(X_train), target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          dws       1.00      1.00      1.00       236
#          jog       1.00      1.00      1.00       265
#          sit       1.00      1.00      1.00       663
#          std       1.00      1.00      1.00       615
#          ups       1.00      1.00      1.00       298
#          wlk       1.00      1.00      1.00       666
#
#     accuracy                           1.00      2743
#    macro avg       1.00      1.00      1.00      2743
# weighted avg       1.00      1.00      1.00      2743

# %%
plot_confusion_matrix(grid_search, X_train, y_train,
                      display_labels=label_encoder.classes_,
                      cmap=plt.cm.Blues,
                      normalize="true")

# %%
print(classification_report(y_test, grid_search.predict(X_test), target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          dws       0.97      0.96      0.96       123
#          jog       1.00      0.99      1.00       119
#          sit       1.00      1.00      1.00       341
#          std       1.00      1.00      1.00       285
#          ups       0.95      0.94      0.95       138
#          wlk       0.98      0.99      0.98       346
#
#     accuracy                           0.99      1352
#    macro avg       0.98      0.98      0.98      1352
# weighted avg       0.99      0.99      0.99      1352

# %%
plot_confusion_matrix(grid_search, X_test, y_test,
                      display_labels=label_encoder.classes_,
                      cmap=plt.cm.Blues,
                      normalize="true")
